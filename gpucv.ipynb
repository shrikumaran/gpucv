# %%
# !pip3 install gpucv
# Out:
# ...
#      |████████████████████████████████| 100 kB 7.6 MB/s
# ...

# %%
import gpucv 
import time 
from matplotlib import pyplot as plt

# %%
# %time img = gpucv.readimg('index.bmp')
# Out:
# CPU times: user 17.2 ms, sys: 3.08 ms, total: 20.3 ms
# Wall time: 21.4 ms

# %%
plt.imshow(img[0])
