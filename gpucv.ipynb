# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikumaran/gpucv/blob/main/gpucv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install gpucv

# %%
import gpucv 
import cv2 
import time 
from matplotlib import pyplot as plt

# %%
img = gpucv.readimg('index.bmp')

# %%
img.shape
# Out:
# (3, 225, 225)

# %%
plt.imshow(img[0])

# %%
sobel = gpucv.sobel(img)

# %%
plt.imshow(sobel)

# %%
cv2.imwrite('sobel.png',sobel)
# Out:
# True
